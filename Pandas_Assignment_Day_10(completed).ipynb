# %% [markdown]
# <a href="https://colab.research.google.com/github/yaser2532/python-basics-/blob/main/Pandas_Assignment_Day_10(completed).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
a = pd.Series([100, 200, 300, 400])
print(a)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %% [markdown]
# Print a, and data type

# %%
print(a)
print(type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
print(a[2])
# Out:
# 300

# %% [markdown]
# What are the values of index for series a?

# %%
print(a.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['c', 'a', 'b', 'd']
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
a['d']
# Out:
# np.int64(400)

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
print(a.sort_index())
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
b = pd.Series([800, 450, 100], index=['e', 'f', 'g'])
print(b)
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
a = pd.concat([a, b])

# %%
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
a = a.sort_values(ascending=False)

# %%
print(a.index)
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
df = pd.DataFrame(a)
print(df)
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200
# c  100
# g  100

# %%
df
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200
# c  100
# g  100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
print(df.shape)
# It mostly implies that the DataFrame has 7 rows and 1 column in this case we have a table with 7 rows and 1 coloum.
# Out:
# (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
print(df.index)
# Yes, the index of the DataFrame is the same as the series 'a' because previouly we changed the index type of the df.
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
print('DataFrame Head:')
print(df.head())
print('\nDataFrame Tail:')
print(df.tail())
# head() represents the first few rows (default 5) and tail() represents the last few rows (default 5).
# Out:
# DataFrame Head:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200
#
# DataFrame Tail:
#      0
# d  400
# b  300
# a  200
# c  100
# g  100

# %%
# Extra space to show head/tail
df.head()
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df = df.rename(columns={0: 'points'})
print(df)
# Out:
#    points
# e     800
# f     450
# d     400
# b     300
# a     200
# c     100
# g     100

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
np.random.seed(42)
fruits = np.random.choice(['orange', 'mango', 'apple'], size=7)

# %%
fruits = pd.Series(fruits)
print(fruits)
# Out:
# 0     apple
# 1    orange
# 2     apple
# 3     apple
# 4    orange
# 5    orange
# 6     apple
# dtype: object

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits.index = df.index
print(fruits)
# Out:
# e     apple
# f    orange
# d     apple
# b     apple
# a    orange
# c    orange
# g     apple
# dtype: object

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df['fruits'] = fruits

# %%
df.head()
# Out:
#    points  fruits
# e     800   apple
# f     450  orange
# d     400   apple
# b     300   apple
# a     200  orange

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
d1 = pd.DataFrame({
    'city': ['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'],
    'Temperature': [15, 22, 20, 26, -2]
})
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
print(d1.shape)
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1['city']

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
d2 = pd.DataFrame({
    'city': ['Bengalaru', 'Coimbatore', 'Srirangam', 'Pondicherry'],
    'Temperature': [24, 35, 36, 39]
})
print(d2)
# Out:
#           city  Temperature
# 0    Bengalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# print the shape of this dataframe

# %%
print(d2.shape)
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
d3 = pd.concat([d1, d2], ignore_index=True)
print(d3)
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 5    Bengalaru           24
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
cities_low_temp = d3[d3['Temperature'] <= 20]
print(cities_low_temp)
print('Number of cities:', len(cities_low_temp))
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2
# Number of cities: 3

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
cities_high_temp = d3[d3['Temperature'] >= 35]
print(cities_high_temp)
# Out:
#           city  Temperature
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
def is_ut(x):
    return x in ['Chandigarh', 'Pondicherry', 'Delhi']

d3['is_ut'] = d3['city'].apply(is_ut)

# %%
print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 5    Bengalaru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
def c_to_f(c):
    return (c * 9/5) + 32

# %%
print(c_to_f(10))
# Out:
# 50.0

# %%
d3['temp_farenhiet'] = d3['Temperature'].apply(c_to_f)
print(d3)
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 0   Chandigarh           15   True            59.0
# 1        Delhi           22   True            71.6
# 2       Kanpur           20  False            68.0
# 3      Chennai           26  False            78.8
# 4       Manali           -2  False            28.4
# 5    Bengalaru           24  False            75.2
# 6   Coimbatore           35  False            95.0
# 7    Srirangam           36  False            96.8
# 8  Pondicherry           39   True           102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
d1_ut = d1[d1['city'].isin(['Chandigarh', 'Pondicherry', 'Delhi'])]
print(d1_ut)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
d1_above_90 = d1[d1['Temperature'].apply(c_to_f) > 90]
print(d1_above_90)
# Out:
# Empty DataFrame
# Columns: [city, Temperature]
# Index: []

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
print(d1.head(3))
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
print(d3.iloc[:, -2:])
# Out:
#    is_ut  temp_farenhiet
# 0   True            59.0
# 1   True            71.6
# 2  False            68.0
# 3  False            78.8
# 4  False            28.4
# 5  False            75.2
# 6  False            95.0
# 7  False            96.8
# 8   True           102.2

# %% [markdown]
# ## Groupby

# %%
data = {
    'Branch': ['CSE', 'ECE', 'CSE', 'ECE', 'CSE', 'ECE', 'MECH', 'MECH'],
    'Year': [1, 1, 2, 2, 1, 2, 1, 2],
    'Students': [120, 100, 110, 90, 115, 95, 80, 85],
    'Placed': [90, 80, 95, 75, 88, 70, 60, 65]
}
df_groupby = pd.DataFrame(data)
print(df_groupby)
# Out:
#   Branch  Year  Students  Placed
# 0    CSE     1       120      90
# 1    ECE     1       100      80
# 2    CSE     2       110      95
# 3    ECE     2        90      75
# 4    CSE     1       115      88
# 5    ECE     2        95      70
# 6   MECH     1        80      60
# 7   MECH     2        85      65

# %%
print(df_groupby.groupby('Branch')[['Students', 'Placed']].sum())
# Out:
#         Students  Placed
# Branch
# CSE          345     273
# ECE          285     225
# MECH         165     125

# %%
print(df_groupby.groupby('Branch')['Students'].count())
# Out:
# Branch
# CSE     3
# ECE     3
# MECH    2
# Name: Students, dtype: int64

# %%
print(df_groupby.groupby('Branch')['Students'].agg(['min', 'max']))
# Out:
#         min  max
# Branch
# CSE     110  120
# ECE      90  100
# MECH     80   85

# %%
print(df_groupby.groupby(['Branch', 'Year'])[['Students', 'Placed']].mean())
# Out:
#              Students  Placed
# Branch Year
# CSE    1        117.5    89.0
#        2        110.0    95.0
# ECE    1        100.0    80.0
#        2         92.5    72.5
# MECH   1         80.0    60.0
#        2         85.0    65.0

# %%
print(df_groupby.groupby(['Branch', 'Year'])['Placed'].agg(['min', 'max']))
# Out:
#              min  max
# Branch Year
# CSE    1      88   90
#        2      95   95
# ECE    1      80   80
#        2      70   75
# MECH   1      60   60
#        2      65   65

# %%
print('Groupby examples completed.')
# Out:
# Groupby examples completed.

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
a = pd.date_range(start='2020-01-01', end='2021-04-01')

# %% [markdown]
# print a

# %%
print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[ns]', length=457, freq='D')

# %% [markdown]
# What is the len of a?

# %%
print(len(a))
# Out:
# 457

# %% [markdown]
# What is the type of a?

# %%
print(type(a))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
print('Assignment complete!')
# Out:
# Assignment complete!
