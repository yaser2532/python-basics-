# %% [markdown]
# <a href="https://colab.research.google.com/github/yaser2532/python-basics-/blob/main/Python_Data_Structure_Assignment_Day_5_(completed).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a id='1'></a><center> <h3 style="background-color:orange; color:white" ><br>Python Data Structures<br></h3>

# %% [markdown]
# # `Types of Data Structures:`
# * `List` | `Tuple`
# * `Set` | `Dictionary`

# %% [markdown]
# |Data Structures type|Mutable|Comments|Indexing|Ordered|Duplicacy|
# |----|----|----|----|----|----|
# tuple ()|immutable|immutable version of list| possible|yes |allowed |
# list []|mutable|-|possible |yes | allowed |
# set {}|mutable| -|not |no |not |
# dict {key:value}|mutable|-|possible |no |not  |

# %% [markdown]
# 💫 `immutable` => `can't be changed` <br>
# 💫 `mutable` => `can be changed`

# %% [markdown]
# ## Lists

# %% [markdown]
# ### Create an empty list with the name ‘a’, print the value of a and type(a).

# %%
# create empty list, name it 'a'
a = []

# %%
# print the value of a
print(a)
# Out:
# []

# %%
# print the type of a
print(type(a))
# Out:
# <class 'list'>

# %% [markdown]
# ### Create a list , languages = ['R','Python', 'SAS', 'Scala', 42],

# %%
# Create a list
languages = ['R','Python', 'SAS', 'Scala', 42]

# %% [markdown]
# Print the number of elements in the list

# %%
# Print the number of elements in the list
print(len(languages))
# Out:
# 5

# %% [markdown]
# Using for loop iterate and print all the elements in the list

# %%
# Using for loop iterate and print all the elements in the list
for iamgreat in languages:
    print(iamgreat)
# Out:
# R
# Python
# SAS
# Scala
# 42

# %% [markdown]
# Select the second item, 'Python' and store it in a new variable named 'temp'

# %%
# Select the second item and store in temp
temp = languages[1]

# %% [markdown]
# Print the value of temp and type(temp)

# %%
# Print value and type
print(temp)
print(type(temp))
# Out:
# Python
# <class 'str'>

# %% [markdown]
# Append the element 'Java' in the list

# %%
# Append Java
languages.append('Java')
print(languages)
# Out:
# ['R', 'Python', 'SAS', 'Scala', 42, 'Java']

# %% [markdown]
# Remove the element 42 from the list and print the list

# %%
# Remove 42
languages.remove(42)
print(languages)
# Out:
# ['R', 'Python', 'SAS', 'Scala', 'Java']

# %% [markdown]
# ### Create a list, colors = [‘Red’, ‘Blue’, ‘White’]

# %%
# Create colors list
colors = ['Red', 'Blue', 'White']

# %% [markdown]
# Append the element 'Black' to colors

# %%
# Append Black
colors.append('Black')
print(colors)
# Out:
# ['Red', 'Blue', 'White', 'Black']

# %% [markdown]
# Append the color 'Orange' to second position (index=1) and print the list

# %%
# Insert Orange at index 1
colors.insert(1, 'Orange')
print(colors)
# Out:
# ['Red', 'Orange', 'Blue', 'White', 'Black']

# %% [markdown]
# Print the list

# %%
# Print list
print(colors)
# Out:
# ['Red', 'Orange', 'Blue', 'White', 'Black']

# %% [markdown]
# Create another list, colors2 = [‘Grey’, ‘Sky Blue’]

# %%
# Create colors2
colors2 = ['Grey', 'Sky Blue']

# %% [markdown]
# Add the elements of colors2 to colors using extend function in the list

# %%
# Extend colors
colors.extend(colors2)
print(colors)
# Out:
# ['Red', 'Orange', 'Blue', 'White', 'Black', 'Grey', 'Sky Blue']

# %% [markdown]
# Print len of colors and its elements

# %%
# Print length and elements
print(len(colors))
print(colors)
# Out:
# 7
# ['Red', 'Orange', 'Blue', 'White', 'Black', 'Grey', 'Sky Blue']

# %% [markdown]
# Sort the list and print it.

# %%
# Sort the list
colors.sort()
print(colors)
# Out:
# ['Black', 'Blue', 'Grey', 'Orange', 'Red', 'Sky Blue', 'White']

# %% [markdown]
# ### Create a string, sent = ‘Coronavirus Caused Lockdowns Around The World.”

# %%
# Create string
sent = "Coronavirus Caused Lockdowns Around The World."

# %% [markdown]
# Use split function to convert the string into a list of words and save it in variable words and print the same

# %%
# Convert string into list
words = sent.split()
print(words)
# Out:
# ['Coronavirus', 'Caused', 'Lockdowns', 'Around', 'The', 'World.']

# %% [markdown]
# Convert each word in the list to lower case and store it in variable words_lower.
# Print words_lower

# %%
# Convert to lowercase
words_lower = [hmm.lower() for hmm in words]
print(words_lower)
# Out:
# ['coronavirus', 'caused', 'lockdowns', 'around', 'the', 'world.']

# %% [markdown]
# Check whether ‘country’ is in the list

# %%
# Check if country is present
if('country' in words_lower):
  print("country is in the list")
else:
    print("country is not in the list")
# Out:
# country is not in the list

# %% [markdown]
# Remove the element ‘the’ from the list and print the list.

# %%
# Remove 'the'
words_lower.remove('the')
print(words_lower)
# Out:
# ['coronavirus', 'caused', 'lockdowns', 'around', 'world']

# %% [markdown]
# Select the first 4 words from the list words_lower using slicing and store them in a new variable x4

# %%
# Select first 4 words
x4 = words_lower[0:4]

# %%
# print x4
print(x4)
# Out:
# ['coronavirus', 'caused', 'lockdowns', 'around']

# %% [markdown]
# Convert the list of elements to single string using join function and print it

# %%
# Convert list into string
result = ' '.join(words_lower)
print(result)
# Out:
# coronavirus caused lockdowns around world

# %% [markdown]
# ## Sets

# %% [markdown]
# ### Create stud_grades = ['A','A','B','C','C','F']

# %%
# Create list
# this is a list not a set
stud_grades = ['A','A','B','C','C','F']

# %% [markdown]
# Print the len of stud_grades

# %%
# Print length
print(len(stud_grades))
# Out:
# 6

# %% [markdown]
# Create a new variable, stud_grades_set = set(stud_grades)

# %%
# Convert into set
stud_grades_set = set(stud_grades)

# %% [markdown]
# Print stud_grades_set.

# %%
# Print set
print(stud_grades_set)
# Out:
# {'B', 'A', 'F', 'C'}

# %% [markdown]
# print the type of stud_grades and stud_grades_set and print their corresponding elements. Try to understand the difference between them.

# %%
# Print types and elements
print(type(stud_grades))
print(type(stud_grades_set))

print(stud_grades)
print(stud_grades_set)

#student grades is a set the values in it can be duplicated and student grade set is a set it's valus can't be duplicated
# Out:
# <class 'list'>
# <class 'set'>
# ['A', 'A', 'B', 'C', 'C', 'F']
# {'B', 'C', 'F', 'A'}

# %% [markdown]
# Add a new element ‘G’ to stud_grades_set

# %%
# Add G
stud_grades_set.add('G')
print(stud_grades_set)
# Out:
# {'A', 'F', 'B', 'C', 'G'}

# %% [markdown]
# Add element 'F' to stud_grades_set. and print it.

# %%
# Add F again
stud_grades_set.add('F')
print(stud_grades_set)
# Out:
# {'A', 'F', 'B', 'C', 'G'}

# %% [markdown]
# !!Did you notice? set doesn't add an element if it's already present in it, unlike lists.

# %% [markdown]
# Remove ‘F’ from stud_grades_set

# %%
# Remove F
stud_grades_set.remove('F')
print(stud_grades_set)
# Out:
# {'A', 'B', 'C', 'G'}

# %% [markdown]
# Print the elements and the length of stud_grades_set

# %%
# Print elements and length
print(stud_grades_set)
print(len(stud_grades_set))
# Out:
# {'A', 'B', 'C', 'G'}
# 4

# %% [markdown]
# ### Create colors = [‘red’,’blue’,’orange’], and fruits = [‘orange’,’grapes’,’apples’]

# %%
# Create lists
colors = ['red','blue','orange']
fruits = ['orange','grapes','apples']

# %% [markdown]
# Print color and fruits

# %%
# Print lists
print(colors)
print(fruits)
# Out:
# ['red', 'blue', 'orange']
# ['orange', 'grapes', 'apples']

# %% [markdown]
# Create colors_set, and fruits_set. (using set() ) and print them

# %%
# Create sets
colors_set = set(colors)
fruits_set = set(fruits)

print(colors_set)
print(fruits_set)
# Out:
# {'blue', 'red', 'orange'}
# {'grapes', 'orange', 'apples'}

# %% [markdown]
# Find the union of both the sets.

# %%
# Union
print(colors_set.union(fruits_set))
# Out:
# {'grapes', 'orange', 'blue', 'red', 'apples'}

# %% [markdown]
# Find the intersection of both the sets

# %%
# Intersection
print(colors_set.intersection(fruits_set))
# Out:
# {'orange'}

# %% [markdown]
# Find the elements which are Fruits but not colors (using set.difference() )

# %%
# Difference
print(fruits_set.difference(colors_set))
# Out:
# {'grapes', 'apples'}

# %% [markdown]
# ## TUPLES

# %% [markdown]
# ### Create temp = [17, ’Virat’, 50.0]

# %%
# Create temp list
temp = [17, 'Virat', 50.0]

# %% [markdown]
# Iterate through temp and print all the items in temp

# %%
# Iterate through temp
for i in temp:
    print(i)
# Out:
# 17
# Virat
# 50.0

# %% [markdown]
# replace first element with 11 in temp

# %%
# Replace first element
temp[0] = 11
print(temp)
# Out:
# [11, 'Virat', 50.0]

# %% [markdown]
# Set temp1 = tuple(temp)

# %%
# Convert to tuple
temp1 = tuple(temp)

# %% [markdown]
# Iterate through temp1 and print all the items in temp1.

# %%
# Iterate tuple
for i in temp1:
    print(i)
# Out:
# 11
# Virat
# 50.0

# %% [markdown]
# replace first element with 17 in temp1

# %%
# Replace first element
temp1[0] = 17
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9279/798955135.py in <cell line: 0>()
#       1 # Replace first element
# ----> 2 temp1[0] = 17
#
# NameError: name 'temp1' is not defined

# %% [markdown]
# <b>Oops!! You got an error. Hey Don't worry! Its because Once a tuple is created, you cannot change its values unlike list.</b>

# %% [markdown]
# ### Create city = ("Bangalore", 28.9949521, 72)

# %%
# Create city tuple
city = ("Bangalore", 28.9949521, 72)

# %% [markdown]
# Print first element of city

# %%
# Print first element
print(city[0])
# Out:
# Bangalore

# %% [markdown]
# Create city2 = (‘Chennai’, 30.01, 74)

# %%
# Create city2
city2 = ('Chennai', 30.01, 74)

# %% [markdown]
# Create cities which consist of city and city2

# %%
# Create nested tuple
cities = (city, city2)

# %% [markdown]
# Print cities

# %%
print(cities)
# Out:
# (('Bangalore', 28.9949521, 72), ('Chennai', 30.01, 74))

# %% [markdown]
# Print type of first element in cities

# %%
# Print type of first element
print(type(cities[0]))
# Out:
# <class 'tuple'>

# %% [markdown]
# print the type of cities

# %%
# Print type of cities
print(type(cities))
# Out:
# <class 'tuple'>

# %% [markdown]
# Hey that implies you made a nested tuples!!

# %% [markdown]
# ## DICTIONARY

# %% [markdown]
# ### Create a dictionary d = {"actor":"Yaser","animal":"cat","earth":2,"list":[23,
#
# ---
#
# 32,12]}

# %%
# Create dictionary
d = {"actor":"Yaser","animal":"cat","earth":2,"list":[23,32,12]}

# %% [markdown]
# Print the value of d[0]

# %%
# Print d[0]
print(d[0])
#i mean it's a good way to learn trial and error but hmm
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9279/2729087885.py in <cell line: 0>()
#       1 # Print d[0]
# ----> 2 print(d[0])
#       3 #i mean it's a good way to learn trial and error but hmm
#
# KeyError: 0

# %% [markdown]
# <b>Oops!! again an error. again a fun fact. Dictionary return the value for key if key is in the dictionary, else throws KeyError
# and we don't have key 0 here :( </b>

# %% [markdown]
# Store the value of d[‘actor’] to a new variable actor.

# %%
# Store actor
actor = d['actor']
#it's the same what is the point

# %% [markdown]
# Print the type of actor

# %%
# Print type
print(type(actor))
# Out:
# <class 'str'>

# %% [markdown]
# Store the value of d[‘list’] in new variable List.

# %%
# Store list
List = d['list']

# %% [markdown]
# Print the type of List.

# %%
# Print type
print(type(List))
# Out:
# <class 'list'>

# %% [markdown]
# Create d1 = { ‘singer’ : ‘Kr$na’ , ‘album’: ‘Still here’, ‘genre’ : ‘hip-hop’}

# %%
# Create d1
d1 = {'singer':'Krishna', 'album':'Still here', 'genre':'hip-hop'}

# %% [markdown]
# Merge d1 into d.

# %%
# Merge d1 into d
d.update(d1)
print(d)
# Out:
# {'actor': 'amir', 'animal': 'cat', 'earth': 2, 'list': [23, 32, 12]}

# %% [markdown]
# print d

# %%
# Print keys
print(d)
# Out:
# {'actor': 'amir', 'animal': 'cat', 'earth': 2, 'list': [23, 32, 12]}

# %% [markdown]
# Print all the keys in d

# %%
# Print keys
print(d.keys())
# Out:
# dict_keys(['actor', 'animal', 'earth', 'list'])

# %% [markdown]
# Print all the values in d

# %%
# Print values
print(d.values())
# Out:
# dict_values(['amir', 'cat', 2, [23, 32, 12]])

# %% [markdown]
# Iterate over d, and print each key, value pair as this - (actor ----> amir)

# %%
# Iterate dictionary
for keys, value in d.items():
    print(keys, "--->", value)
# Out:
# actor ---> Yaser
# animal ---> cat
# earth ---> 2
# list ---> [23, 32, 12]

# %% [markdown]
# count the number of occurences of charachters in string named "sent" using dictionary and print the same.

# %%
# Count characters using dictionary
sent = "Coronavirus Caused Lockdowns Around The World"

count = {}

for char in sent:
    if char in count:
        count[char] += 1
    else:
        count[char] = 1

print(count)
# Out:
# {'C': 2, 'o': 6, 'r': 4, 'n': 3, 'a': 2, 'v': 1, 'i': 1, 'u': 3, 's': 3, ' ': 5, 'e': 2, 'd': 4, 'L': 1, 'c': 1, 'k': 1, 'w': 1, 'A': 1, 'T': 1, 'h': 1, 'W': 1, 'l': 1}
